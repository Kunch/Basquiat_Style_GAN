# %%
# !pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 74kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.2
#     Uninstalling scipy-1.3.2:
#       Successfully uninstalled scipy-1.3.2
# ...

# %%
from PIL import Image
import os as os
import scipy
import time
import sys
from skimage.io import imread
from tqdm import tqdm
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
 cd /content/drive/"My Drive"/"Colab Notebooks"/"Final_Project/"
# Out:
# /content/drive/My Drive/Colab Notebooks/Final_Project

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Final_Project'

# %%
list_file = []
#list_buf = os.listdir('Data4/')
for i in range(1200,1251,4):
  list_file.append(str(i)+'.png')

# %%
image_obj = Image.open('d5_4r1.png')
newsize = (500, 420) 
im1 = image_obj.resize(newsize) 
im1.save('Data4_resize/4r1.png')

# %%
count = 1
for filename in list_file:
    image_obj = Image.open('Data4/'+filename)
    newsize = (500, 420) 
    im1 = image_obj.resize(newsize) 
    im1.save('Data4_resize/4r'+str(count)+'.png')
    count +=1

# %% [markdown]
# ### **Super Resolution -------------------------**

# %%
cd /content/drive/"My Drive"/"Colab Notebooks"/"Final_Project"
# Out:
# /content/drive/My Drive/Colab Notebooks/Final_Project

# %%
#Get img from data4c one by one
import warnings
warnings.filterwarnings("ignore")
import os
import tensorflow as tf
list_4c = sorted(os.listdir('Data4_resize'))
print(list_4c)
for filename in list_4c:
  try:
    os.chdir('enhancenet_pretrained')
  except IOError:
    pass
  os.chdir('..')
  img_st = Image.open(str('Data4_resize/'+filename))
  os.chdir('enhancenet_pretrained')
  path_n = os.listdir('input/')
  path_o = os.listdir('output/')
  if path_n: #check if the folder is not empty
     os.remove('input/'+str(path_n[0]))
     print("Clear input")
  if path_o: #check if the folder is not empty
     os.remove('output/'+str(path_o[0]))
     print("Clear output")
  if not path_n: #check if the folder is empty
    print('Clear to proceed')
    img_st.save('input/'+str(filename))
    time.sleep(5) # Delay for 5 seconds.
    print('processing :' + str(filename) )
    for i in range(11):  #----------------------------------------------------SET ROUND HERE-----------------------------<<<<<<<<<<<<<<<<<<<
       # !python -W ignore enhancenet.py #creat output in output file
       time.sleep(5) # Delay for 5 seconds.
       list_buffer = os.listdir('output')
       list_buffer_in = os.listdir('input')

       path_out = 'output/'+str(list_buffer[0])
       path_in = 'input/'+str(list_buffer_in[0])

       img_buffer = Image.open(path_out)
       os.remove(path_out) 
       os.remove(path_in)

       img_buffer.save('input/' + str(i+1) + '.png')
       print(str(filename) +'__round__'+ str(i+1))
       time.sleep(5) # Delay for 5 seconds.
    os.chdir('..')
    img_buffer.save('Data5/d5_'+str(filename))
    time.sleep(5) # Delay for 5 seconds.
# Out:
# ['4r1.png', '4r10.png', '4r11.png', '4r12.png', '4r13.png', '4r2.png', '4r3.png', '4r4.png', '4r5.png', '4r6.png', '4r7.png', '4r8.png', '4r9.png']
# Clear input
# Clear to proceed
# processing :4r10.png
# WARNING:tensorflow:From enhancenet.py:20: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/Final_Project/enhancenet_pretrained/nnlib.py:54: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...
